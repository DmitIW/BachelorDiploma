# %%
import time

from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import TensorBoard

from model import *
from data import *
import ImageTB
# Out:
# Using TensorFlow backend.

# %%
unet_m = unet_modify(pretrained_weights='./models/Unet_modify_500.29-0.99.hdf5')
MODELS = [
{'model_name':'Unet_modify_500',
           'model' : unet_m,
           'train':'data/sky/iphone_500',
           'val'  :'data/sky/iphone_500',
         'icm' : 'rgb'},]

LOGS_PATH = './../../../log'
if not os.path.exists(LOGS_PATH):
    os.makedirs(LOGS_PATH)
    
WEIGHTS_PATH = './models'
if not os.path.exists(WEIGHTS_PATH):
    os.makedirs(WEIGHTS_PATH)
    
BATCH_SIZE = 5
VAL_BATCH_SIZE = 5
EPOCH = 50
# Out:
# /home/dmitrii/.virtenvs/FaceIidentification/lib/python3.6/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# /home/dmitrii/sky_detect/Semantic-Segmentation-Suite/UNET/sky-segmentation/keras_unet/model.py:79: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)

# %%
data_gen_args = dict(
    rotation_range=0.3,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
for model in MODELS:
    lr_reducer = ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=3, verbose=1, min_lr=1e-6)

    weights_name = model['model_name'] + '.{epoch:02d}-{val_acc:.2f}.hdf5'
    weights_dir = os.path.join(WEIGHTS_PATH, weights_name)
    checkpoint = ModelCheckpoint(weights_dir, monitor='acc', verbose=1, save_best_only=True, mode='max')

    train_generator = BatchGenerator(
        batch_size=BATCH_SIZE,
        train_path=model['train'],
        image_folder='train',
        mask_folder='train_labels',
        aug_dict=data_gen_args,
        save_to_dir = None,
        image_color_mode = model['icm']
    )

    val_generator = BatchGenerator(
        batch_size=VAL_BATCH_SIZE,
        train_path=model['val'],
        image_folder='val',
        mask_folder='val_labels',
        aug_dict=data_gen_args,
        save_to_dir = None,
        image_color_mode = model['icm'])

    CURRENT_TIME = str(time.strftime("%Y%m%d-%H%M%S"))    
    log_name = "{}_{}".format(model['model_name'], CURRENT_TIME)
    log_dir = os.path.join(LOGS_PATH, log_name)
    os.makedirs(log_dir)
    tbCallBack = ImageTB.ImagesTensorBoard(log_dir=log_dir, generator=val_generator)

    model = model['model']

    model.fit_generator(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=EPOCH,
        callbacks=[
                lr_reducer,
                tbCallBack,
                checkpoint,
    #             erlStopping
            ],
        validation_data=val_generator,
        validation_steps=len(val_generator),

        max_queue_size=8,
        workers=4,
        use_multiprocessing=True)
# Out:
# Found 500 images belonging to 1 classes.
# Found 500 images belonging to 1 classes.
# Found 26 images belonging to 1 classes.
# Found 26 images belonging to 1 classes.
# Epoch 1/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.0218 - acc: 0.9918Epoch 1/50
# 100/100 [==============================] - 67s 670ms/step - loss: 0.0220 - acc: 0.9917 - val_loss: 0.0325 - val_acc: 0.9888
#
# Epoch 00001: acc improved from -inf to 0.99170, saving model to ./models/Unet_modify_500.01-0.99.hdf5
# Epoch 2/50
# 100/100 [==============================] - 46s 462ms/step - loss: 0.0272 - acc: 0.9908 - val_loss: 0.0541 - val_acc: 0.9794
#
# Epoch 00002: acc did not improve from 0.99170
# Epoch 3/50
# 100/100 [==============================] - 49s 488ms/step - loss: 0.0307 - acc: 0.9899 - val_loss: 0.1821 - val_acc: 0.9522
#
# Epoch 00003: acc did not improve from 0.99170
# Epoch 4/50
# 100/100 [==============================] - 48s 477ms/step - loss: 0.0527 - acc: 0.9839 - val_loss: 0.0598 - val_acc: 0.9806
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 00004: acc did not improve from 0.99170
# Epoch 5/50
# 100/100 [==============================] - 48s 479ms/step - loss: 0.0258 - acc: 0.9906 - val_loss: 0.0208 - val_acc: 0.9915
#
# Epoch 00005: acc did not improve from 0.99170
# Epoch 6/50
# 100/100 [==============================] - 48s 476ms/step - loss: 0.0185 - acc: 0.9930 - val_loss: 0.0311 - val_acc: 0.9888
#
# Epoch 00006: acc improved from 0.99170 to 0.99299, saving model to ./models/Unet_modify_500.06-0.99.hdf5
# Epoch 7/50
# 100/100 [==============================] - 46s 465ms/step - loss: 0.0162 - acc: 0.9940 - val_loss: 0.0216 - val_acc: 0.9916
#
# Epoch 00007: acc improved from 0.99299 to 0.99400, saving model to ./models/Unet_modify_500.07-0.99.hdf5
# Epoch 8/50
# 100/100 [==============================] - 47s 469ms/step - loss: 0.0149 - acc: 0.9944 - val_loss: 0.0208 - val_acc: 0.9921
#
# Epoch 00008: acc improved from 0.99400 to 0.99440, saving model to ./models/Unet_modify_500.08-0.99.hdf5
# Epoch 9/50
# 100/100 [==============================] - 47s 472ms/step - loss: 0.0132 - acc: 0.9949 - val_loss: 0.0195 - val_acc: 0.9927
#
# Epoch 00009: acc improved from 0.99440 to 0.99493, saving model to ./models/Unet_modify_500.09-0.99.hdf5
# Epoch 10/50
# 100/100 [==============================] - 46s 464ms/step - loss: 0.0135 - acc: 0.9948 - val_loss: 0.0165 - val_acc: 0.9936
#
# Epoch 00010: acc did not improve from 0.99493
# Epoch 11/50
# 100/100 [==============================] - 47s 474ms/step - loss: 0.0139 - acc: 0.9949 - val_loss: 0.0191 - val_acc: 0.9929
#
# Epoch 00011: acc did not improve from 0.99493
# Epoch 12/50
# 100/100 [==============================] - 47s 471ms/step - loss: 0.0120 - acc: 0.9953 - val_loss: 0.0204 - val_acc: 0.9923
#
# Epoch 00012: acc improved from 0.99493 to 0.99534, saving model to ./models/Unet_modify_500.12-0.99.hdf5
# Epoch 13/50
# 100/100 [==============================] - 47s 467ms/step - loss: 0.0122 - acc: 0.9953 - val_loss: 0.0166 - val_acc: 0.9937
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 00013: acc did not improve from 0.99534
# Epoch 14/50
# 100/100 [==============================] - 47s 471ms/step - loss: 0.0113 - acc: 0.9956 - val_loss: 0.0207 - val_acc: 0.9927
#
# Epoch 00014: acc improved from 0.99534 to 0.99561, saving model to ./models/Unet_modify_500.14-0.99.hdf5
# Epoch 15/50
# 100/100 [==============================] - 47s 467ms/step - loss: 0.0109 - acc: 0.9958 - val_loss: 0.0175 - val_acc: 0.9935
#
# Epoch 00015: acc improved from 0.99561 to 0.99577, saving model to ./models/Unet_modify_500.15-0.99.hdf5
# Epoch 16/50
# 100/100 [==============================] - 47s 473ms/step - loss: 0.0112 - acc: 0.9957 - val_loss: 0.0180 - val_acc: 0.9935
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 00016: acc did not improve from 0.99577
# Epoch 17/50
# 100/100 [==============================] - 47s 467ms/step - loss: 0.0108 - acc: 0.9958 - val_loss: 0.0184 - val_acc: 0.9934
#
# Epoch 00017: acc improved from 0.99577 to 0.99580, saving model to ./models/Unet_modify_500.17-0.99.hdf5
# Epoch 18/50
# 100/100 [==============================] - 48s 477ms/step - loss: 0.0104 - acc: 0.9960 - val_loss: 0.0168 - val_acc: 0.9939
#
# Epoch 00018: acc improved from 0.99580 to 0.99596, saving model to ./models/Unet_modify_500.18-0.99.hdf5
# Epoch 19/50
# 100/100 [==============================] - 46s 465ms/step - loss: 0.0106 - acc: 0.9959 - val_loss: 0.0152 - val_acc: 0.9943
#
# Epoch 00019: acc did not improve from 0.99596
# Epoch 20/50
# 100/100 [==============================] - 48s 476ms/step - loss: 0.0104 - acc: 0.9959 - val_loss: 0.0161 - val_acc: 0.9942
#
# Epoch 00020: acc did not improve from 0.99596
# Epoch 21/50
# 100/100 [==============================] - 48s 482ms/step - loss: 0.0106 - acc: 0.9959 - val_loss: 0.0153 - val_acc: 0.9944
# /home/dmitrii/.virtenvs/FaceIidentification/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 00021: acc did not improve from 0.99596
# Epoch 22/50
# 100/100 [==============================] - 47s 474ms/step - loss: 0.0105 - acc: 0.9960 - val_loss: 0.0177 - val_acc: 0.9939
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 00022: acc improved from 0.99596 to 0.99597, saving model to ./models/Unet_modify_500.22-0.99.hdf5
# Epoch 23/50
# 100/100 [==============================] - 47s 469ms/step - loss: 0.0100 - acc: 0.9961 - val_loss: 0.0169 - val_acc: 0.9941
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 00023: acc improved from 0.99597 to 0.99608, saving model to ./models/Unet_modify_500.23-0.99.hdf5
# Epoch 24/50
# 100/100 [==============================] - 47s 466ms/step - loss: 0.0098 - acc: 0.9961 - val_loss: 0.0184 - val_acc: 0.9937
#
# Epoch 00024: acc improved from 0.99608 to 0.99614, saving model to ./models/Unet_modify_500.24-0.99.hdf5
# Epoch 25/50
# 100/100 [==============================] - 47s 469ms/step - loss: 0.0095 - acc: 0.9962 - val_loss: 0.0193 - val_acc: 0.9935
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 00025: acc improved from 0.99614 to 0.99623, saving model to ./models/Unet_modify_500.25-0.99.hdf5
# Epoch 26/50
# 100/100 [==============================] - 48s 477ms/step - loss: 0.0097 - acc: 0.9962 - val_loss: 0.0160 - val_acc: 0.9943
#
# Epoch 00026: acc did not improve from 0.99623
# Epoch 27/50
# 100/100 [==============================] - 48s 482ms/step - loss: 0.0100 - acc: 0.9960 - val_loss: 0.0185 - val_acc: 0.9935
#
# Epoch 00027: acc did not improve from 0.99623
# Epoch 28/50
# 100/100 [==============================] - 48s 479ms/step - loss: 0.0106 - acc: 0.9961 - val_loss: 0.0184 - val_acc: 0.9936
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 00028: acc did not improve from 0.99623
# Epoch 29/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.9963
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 100/100 [==============================] - 48s 479ms/step - loss: 0.0100 - acc: 0.9962 - val_loss: 0.0159 - val_acc: 0.9943
#
# Epoch 00029: acc did not improve from 0.99623
# Epoch 30/50
# 100/100 [==============================] - 48s 479ms/step - loss: 0.0103 - acc: 0.9961 - val_loss: 0.0161 - val_acc: 0.9943
#
# Epoch 00030: acc did not improve from 0.99623
# Epoch 31/50
#  21/100 [=====>........................] - ETA: 43s - loss: 0.0089 - acc: 0.9965
